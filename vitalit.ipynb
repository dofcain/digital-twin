# %% [markdown]
# <a href="https://colab.research.google.com/github/dofcain/digital-twin/blob/main/vitalit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase-admin

# %%
from google.colab import files
uploaded = files.upload()   # choose servicekey.json from your PC
# Out:
#      <input type="file" id="files-bcce4657-6a8e-4124-a201-ca99366191c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcce4657-6a8e-4124-a201-ca99366191c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import firebase_admin
from firebase_admin import credentials, db

# Use the uploaded key file
cred = credentials.Certificate("servicekey.json")
firebase_admin.initialize_app(cred, {
    'databaseURL': "https://digital-twin-vitalit-default-rtdb.firebaseio.com/"
})

# %%
import firebase_admin
from firebase_admin import credentials, db
import random, time
from datetime import datetime

while True:
    systolic = random.randint(100, 130)
    diastolic = random.randint(70, 90)

    data = {
        "heart_rate": random.randint(60, 100),
        "SpO2": random.randint(90, 100),
        "temperature": round(random.uniform(36.0, 37.5), 1),
        "blood_pressure": f"{systolic}/{diastolic}",
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }

    # 🔹 Store under "patient_history" (not patient_data)
    ref = db.reference("patient_history")
    ref.push(data)

    print("Uploaded to Firebase:", data)
    time.sleep(2)
# Out:
# Uploaded to Firebase: {'heart_rate': 79, 'SpO2': 99, 'temperature': 36.4, 'blood_pressure': '127/76', 'timestamp': '2025-11-05 12:14:59'}
# Uploaded to Firebase: {'heart_rate': 79, 'SpO2': 92, 'temperature': 37.5, 'blood_pressure': '107/75', 'timestamp': '2025-11-05 12:15:01'}
# Uploaded to Firebase: {'heart_rate': 95, 'SpO2': 94, 'temperature': 36.5, 'blood_pressure': '113/82', 'timestamp': '2025-11-05 12:15:03'}
# Uploaded to Firebase: {'heart_rate': 63, 'SpO2': 90, 'temperature': 37.1, 'blood_pressure': '122/72', 'timestamp': '2025-11-05 12:15:05'}
# Uploaded to Firebase: {'heart_rate': 91, 'SpO2': 92, 'temperature': 36.1, 'blood_pressure': '102/72', 'timestamp': '2025-11-05 12:15:07'}
# Uploaded to Firebase: {'heart_rate': 66, 'SpO2': 90, 'temperature': 36.7, 'blood_pressure': '116/81', 'timestamp': '2025-11-05 12:15:09'}
# Uploaded to Firebase: {'heart_rate': 68, 'SpO2': 93, 'temperature': 36.9, 'blood_pressure': '118/83', 'timestamp': '2025-11-05 12:15:12'}
# ...
